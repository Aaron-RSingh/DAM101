# %%
# what would be the output of the following code:

a = 0
for l in range(0, 12, 3):
    for s in range(0, -14, -2):
        a += 1
print(a)
# Out:
# 28

# %%
# you need a program that reads an integer from the console, stores it in a variable called a and prints it if the value entered is less than or equal to 3.

a = int(input("enter an integer: "))
if a <= 3:
    print(a)
# Out:
# 1

# %%
d = 8
if(d<7):
    d*=7
print(d)
# Out:
# 8

# %%
b = 6
z = 0
while b > 0:
    q=0
    while q<5:
        q += 1
        z += 1
    b-=4
print(z)
# Out:
# 10

# %%
l = 0
while l < 20:
    z = z+5
    l += 1

# %%
v = 1
while v < 4:
    if v%4==0:
        print(v)
    v+=1

# %%
c = 0
while c < 12:
    c +=2

# %%
b = 0
while b < 7:
    b+=3

# %%
s = 0
while s<14:
    s +=1

# %%
s = 0
while s<12:
    s+=2

# %%
for g in range(0, 14, 3):
    print(g)
# Out:
# 0
# 3
# 6
# 9
# 12

# %%
Apples = 8
Bananas = 15
Oranges = 14
Lemons = 10

Fruit1 = Lemons == Apples
Fruit2 = Lemons > Apples
Fruit3 = Bananas < Oranges
Fruit4 = Apples != Oranges

print(Fruit3)
# Out:
# False

# %%
x = 0
a = -1
b = -10
if a > 0:
    x += 5
elif b < 0:
    x += 4
else:
    x += 3

print(x)
# Out:
# 4

# %%
s = 1
for w in range(0, 7, 3):
    s *= 5
    print(s)
print(s)
# Out:
# 5
# 25
# 125
# 125

# %%
o = 0
for e in range(0, 4, 2):
    o+=1

# %%
t = 0
for e in range(0, 1, 4):
    t+= 4

# %%
t = 0
for for in range(0, 7, 2):
    t+=3
# Out:
#   Cell In[30], line 2
#     for for in range(0, 7, 2):
#         ^
# SyntaxError: invalid syntax

# %%
x = 0
for d in range0, 9, 2):
    x += 3
# Out:
#   Cell In[31], line 2
#     for d in range0, 9, 2):
#                          ^
# SyntaxError: unmatched ')'
