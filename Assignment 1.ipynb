# %% [markdown]
# # PandA Final Exam Question 1

# %% [markdown]
# 1. You are given the following uncommented code for function foo:
#
#          def foo(ts):
#
#             return [t * 2 for t in ts if t[0].lower() in "aeiou"]
#
# i) Provide a commented version of the code above. Using a docstring explain the purpose of this piece of code.
#
# ii) Rewrite the code using a for loop instead of list comprehension, maintatin the same functionality. Using a docstring exaplin the purpose of this piece of code. Provide clear and concise comments explaining the function of the code written.

# %%
# i)


def foo(ts):
    """
    This function uses list comprehension to check the first character of each element in a list of strings, where the first character is a vowel, it duplicates the string and adds it to the output list.

    The argument should be a list of strings and be alphabetic and not numerical.

    Output is a list of duplicated strings that started with a vowel.
    """
    return [t*2 for t in ts if t[0].lower() in "aeiou"]

# Below is a test case to demonstrate the functionality of the 'foo' function. It creates a list of fruits and then calls the 'foo' function with that list, printing the result. Output: ['appleapple', 'orangeorange', 'avocadoavocado']

fruits = ["apple", "banana", "orange", "grape", "avocado"]

# Below is a test case to see if the function would also work with a single string instead of a list. This treats the single string as a list of characters and then  duplicates and returns the vowels in the list of characters. Output: ['aa', 'ee']

fruit = 'apple'

result = foo(fruits)
print(result)
# Out:
# ['appleapple', 'orangeorange', 'avocadoavocado']

# %%
# ii)

def foo(ts):
   """
   This function checks the first character of each element in a list of strings, when the first character is a vowel, it will be duplicated and added to the output list to be returned.

   The arguement should be a list of strings and be alphabetic and not numerical.

   Output is a list of duplicated strings that started with a vowel.
   """
# Create an empty list to hold the results
   results = []
        # Start the loop
   for t in ts:
            # Check if the first character is a vowel
        if t[0].lower() in "aeiou":
            # If it is, add the string and duplicate is to the results list
           results.append(t*2)
    # Return the updated results list
   return results


fruits = ["apple", "banana", "orange", "grape", "avocado"]

print(foo(fruits))
# Out:
# ['appleapple', 'orangeorange', 'avocadoavocado']
